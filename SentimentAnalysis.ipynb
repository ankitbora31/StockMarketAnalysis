# %%
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from urllib.request import urlopen
from urllib.request import Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Parameters 
n = 3 #the # of article headlines displayed per ticker
tickers = ['AAPL', 'TSLA', 'AMZN']

# Get Data
finviz_url = 'https://finviz.com/quote.ashx?t='
news_tables = {}

for ticker in tickers:
    url = finviz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    resp = urlopen(req)    
    html = BeautifulSoup(resp, features="lxml")
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table

try:
    for ticker in tickers:
        df = news_tables[ticker]
        df_tr = df.findAll('tr')
    
        print ('\n')
        print ('Recent News Headlines for {}: '.format(ticker))
        
        for i, table_row in enumerate(df_tr):
            a_text = table_row.a.text
            td_text = table_row.td.text
            td_text = td_text.strip()
            print(a_text,'(',td_text,')')
            if i == n-1:
                break
except KeyError:
    pass

# Iterate through the news
parsed_news = []
for file_name, news_table in news_tables.items():
    for x in news_table.findAll('tr'):
        text = x.a.get_text() 
        date_scrape = x.td.text.split()

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        ticker = file_name.split('_')[0]
        
        parsed_news.append([ticker, date, time, text])

# Sentiment Analysis
analyzer = SentimentIntensityAnalyzer()

columns = ['Ticker', 'Date', 'Time', 'Headline']
news = pd.DataFrame(parsed_news, columns=columns)
scores = news['Headline'].apply(analyzer.polarity_scores).tolist()

df_scores = pd.DataFrame(scores)
news = news.join(df_scores, rsuffix='_right')

# View Data 
news['Date'] = pd.to_datetime(news.Date).dt.date

unique_ticker = news['Ticker'].unique().tolist()
news_dict = {name: news.loc[news['Ticker'] == name] for name in unique_ticker}

values = []
for ticker in tickers: 
    dataframe = news_dict[ticker]
    dataframe = dataframe.set_index('Ticker')
    dataframe = dataframe.drop(columns = ['Headline'])
    print ('\n')
    print (dataframe.head())
    
    mean = round(dataframe['compound'].mean(), 2)
    values.append(mean)
    
df = pd.DataFrame(list(zip(tickers, values)), columns =['Ticker', 'Mean Sentiment']) 
df = df.set_index('Ticker')
df = df.sort_values('Mean Sentiment', ascending=False)
print ('\n')
print (df)
# Out:
# Recent News Headlines for AAPL:
# Dow Jones Slides As Apple Sells Off; 4 Top Growth Stocks To Buy And Watch ( Sep-17-21 11:54AM )
# Apple Store goes down ahead of release of iPhone 13 ( 11:20AM )
# Apple Watch series 7: When can you pre-order the new wearable in the UK? ( 10:54AM )
#
#
# Recent News Headlines for TSLA:
# Is Lucid Motors Stock A Buy Right As Lucid Air Gets EPA Rating Of 520 Miles Per Charge? ( Sep-17-21 10:21AM )
# Powell orders ethics review amid trading scandal ( 09:45AM )
# How A.I. will exacerbate inequality between rich & poor: Kai-Fu Lee ( 09:34AM )
#
#
# Recent News Headlines for AMZN:
# Amazon Says More Than 1 Million People Applied for Jobs During Career Day Event ( Sep-17-21 11:01AM )
# Uncertainty around taxes could cause stocks to pullback this month, strategist warns ( 10:46AM )
# KKR Lends $469 Million for Amazon Office Tower Outside Seattle ( 10:32AM )
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# AAPL    2021-09-17  11:54AM  0.000  0.732  0.268    0.5267
# AAPL    2021-09-17  11:20AM  0.000  1.000  0.000    0.0000
# AAPL    2021-09-17  10:54AM  0.000  1.000  0.000    0.0000
# AAPL    2021-09-17  10:46AM  0.275  0.725  0.000   -0.4215
# AAPL    2021-09-17  10:03AM  0.000  1.000  0.000    0.0000
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# TSLA    2021-09-17  10:21AM  0.000  1.000  0.000    0.0000
# TSLA    2021-09-17  09:45AM  0.326  0.674  0.000   -0.4404
# TSLA    2021-09-17  09:34AM  0.211  0.544  0.245    0.1280
# TSLA    2021-09-17  09:00AM  0.000  0.826  0.174    0.2263
# TSLA    2021-09-17  08:44AM  0.000  0.741  0.259    0.4215
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# AMZN    2021-09-17  11:01AM  0.000  0.876  0.124    0.1779
# AMZN    2021-09-17  10:46AM  0.275  0.725  0.000   -0.4215
# AMZN    2021-09-17  10:32AM  0.000  0.841  0.159    0.1779
# AMZN    2021-09-17  09:57AM  0.000  1.000  0.000    0.0000
# AMZN    2021-09-17  09:34AM  0.211  0.544  0.245    0.1280
#
#
#         Mean Sentiment
# Ticker
# AMZN              0.12
# TSLA              0.09
# AAPL              0.04
